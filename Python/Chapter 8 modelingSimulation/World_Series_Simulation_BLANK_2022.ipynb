# %% [markdown]
# # Baseball World Series Simulation
# ## On average, how many games (out of 7) does it take for a team to World Series?
# * An American League (AL) baseball team is considered to have a 60% chance of beating the National League (NL) team in any given World Series game. A team wins the World Series by being the first to win four individual games.

# %% [markdown]
# ### Individual game
# * Generate a random integer between 1 and 100
#  * #'s 1-60 will represent an American League (AL) team win
#    * 60% chance to win
#  * #'s 61-100 will represent a National League (NL) team win
#    * 40% chance to win

# %%
# Import the numpy package
import numpy as np

# Generate random number between 1-100
randint = np.random.randint(1, 101)


# Test the percentage ranges
if randint < 61:
    winner = "AL"
else:
    winner = "NL:"

print(winner)
# Out:
# AL

# %% [markdown]
# #### Copy and paste code into a function
# * Return a String of the winning division
# * Abstraction!

# %%
# Create function that represents one game being played
def one_game():
    chance = np.random.randint(1, 101)
    if chance < 61:
        winner = "AL"
    else:
        winner = "NL"
    return winner

one_game()
# Out:
# 'AL'

# %% [markdown]
# ### Individual World Series
# * Create two variables for AL and NL win counts
# * While both counts are below 4 wins, play a single game
#   * Update variables appropriately
# * Return a tuple in the form (winning division,total games played)

# %%
# Import the numpy package
import numpy as np


# Create variables
al_victories = 0
nl_victories = 0
total_games = 0
        
# While loop
while nl_victories < 4 and al_victories < 4:
    outcome = one_game()
    if outcome is "AL":
        al_victories += 1
    else:
        nl_victories += 1
    total_games += 1

if nl_victories > al_victories:
    winner = "National League"
else:
    winner = "American League"


# Total games played before a division reached four wins

# Print winner and games
print(winner, "Wins!")
print("Total games played before a division reached four wins:", total_games)
# Out:
# American League Wins!
# Total games played before a division reached four wins: 6

# %% [markdown]
# ## Defining an individual trial
# #### Copy and paste code into a function
# * Return a tuple in the format (winning division, total number of games played)
# * Abstraction!

# %%
# Create function to represent one trial of a World Series 
def single_trial():
    # Create variables
    al_victories = 0
    nl_victories = 0
    total_games = 0
            
    # While loop
    while nl_victories < 4 and al_victories < 4:
        outcome = one_game()
        if outcome is "AL":
            al_victories += 1
        else:
            nl_victories += 1
        total_games += 1

    if nl_victories > al_victories:
        winner = "National League"
    else:
        winner = "American League"


    return winner, total_games

single_trial()
# Out:
# ('American League', 4)

# %% [markdown]
# ### Finding the average number of total games played to win a World Series
# #### Simulate a large number of individual trials of a World Series, analyze the results
# * Create an array to hold your results
# * Create a loop to run 10,000 times
#     * Add results of a single World Series to the array

# %%
results = []

# Create a loop that repeats a large number of trials (World Series), in this case 10,000
for i in range(10000):
    results.append(single_trial())

print(results)

# Create variables
winner_arr = []
total_arr = []

for i in range(10000):
    winner, total = single_trial()
    winner_arr.append(winner)
    total_arr.append(total)
    
# Print the results
print(winner_arr, total_arr)
# Out:
# [('American League', 7), ('American League', 7), ('National League', 7), ('American League', 7), ('American League', 5), ('American League', 7), ('National League', 6), ('American League', 7), ('American League', 6), ('American League', 4), ('National League', 6), ('National League', 6), ('American League', 7), ('National League', 6), ('American League', 7), ('National League', 7), ('American League', 5), ('National League', 6), ('American League', 4), ('American League', 5), ('National League', 6), ('National League', 7), ('American League', 5), ('American League', 7), ('American League', 6), ('National League', 7), ('American League', 6), ('American League', 5), ('National League', 6), ('National League', 7), ('American League', 6), ('American League', 5), ('American League', 7), ('National League', 6), ('American League', 4), ('American League', 4), ('National League', 7), ('American League', 6), ('American League', 6), ('National League', 6), ('American League', 7), ('American League', 7), ('National League', 4), ('American League', 5), ('American League', 6), ('National League', 6), ('American League', 7), ('American League', 4), ('National League', 5), ('American League', 5), ('American League', 5), ('American League', 5), ('American League', 5), ('National League', 7), ('American League', 6), ('American League', 7), ('National League', 7), ('American League', 7), ('National League', 4), ('American League', 4), ('American League', 4), ('American League', 5), ('American League', 5), ('American League', 7), ('American League', 6), ('National League', 6), ('American League', 5), ('American League', 5), ('American League', 5), ('American League', 4), ('National League', 6), ('American League', 5), ('American League', 5), ('National League', 6), ('American League', 5), ('American League', 4), ('American League', 5), ('National League', 6), ('American League', 6), ('National League', 5), ('American League', 4), ('American League', 4), ('American League', 5), ('National League', 6), ('American League', 5), ('American League', 7), ('American League', 4), ('American League', 7), ('National League', 5), ('National League', 7), ('American League', 4), ('American League', 5), ('American League', 4), ('American League', 5), ('American League', 5), ('National League', 6), ('National League', 6), ('American League', 7), ('American League', 7), ('American League', 5), ('American League', 5), ('American League', 5), ('American League', 7), ('National League', 7), ('National League', 6), ('American League', 5), ('National League', 5), ('American League', 5), ('American League', 5), ('National League', 4), ('American League', 5), ('National League', 7), ('American League', 4), ('American League', 6), ('American League', 6), ('National League', 7), ('American League', 7), ('American League', 6), ('National League', 7), ('American League', 7), ('American League', 6), ('National League', 6), ('National League', 7), ('American League', 5), ('American League', 5), ('American League', 4), ('National League', 7), ('American League', 4), ('American League', 5), ('National League', 7), ('American League', 6), ('American League', 4), ('American League', 5), ('National League', 5), ('American League', 7), ('American League', 4), ('National League', 7), ('American League', 5), ('National League', 5), ('National League', 7), ('National League', 7), ('American League', 7), ('American League', 4), ('National League', 5), ('American League', 4), ('American League', 6), ('American League', 5), ('American League', 5), ('American League', 6), ('American League', 5), ('National League', 5), ('American League', 6), ('American League', 6), ('American League', 6), ('American League', 5), ('National League', 7), ('National League', 5), ('American League', 5), ('American League', 7), ('American League', 4), ('American League', 5), ('American League', 7), ('American League', 7), ('National League', 4), ('American League', 6), ('American League', 6), ('American Leag ...
# ['American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'National League', 'National League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American ...

# %% [markdown]
# ### Analyze the results

# %% [markdown]
# #### Find the counts of each number of total games (How many times did it take 4, 5, 6, 7 games to win?)
# * Create an array to hold the results
# * Loop through each tuple, read second value (total games played)
# * Add the value to array

# %%
# Create variables
winner_arr = []
total_arr = []

# Loop through each individual trial within the ws_results array
    # Store second value of the tuple at index 1 (total number of games)
    # Add game total to the total_games_array
for result in results:
    winner_arr.append(result[0])
    total_arr.append(result[1])
    


# Print results
print(winner_arr, total_arr)
# Out:
# ['American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'National League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'National League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'National League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National ...

# %% [markdown]
# #### Create bins for each total

# %%
# Create the bin
total_bincount = np.bincount(total_arr)

# Print the results
print(total_bincount)
# Out:
# [   0    0    0    0 1540 2694 3005 2761]

# %%
# Make sure this adds to 10,000 trials!
len(total_arr)
# Out:
# 10000

# %% [markdown]
# #### Calculate the average number of games played in each trial
# * This will represent the average number of games played to win the World Series after 10,000 trials

# %%
# Use np.average(array)

np.average(total_arr)
# Out:
# 5.6987

# %% [markdown]
# ### Graph the results

# %% [markdown]
# #### Histogram
# * Frequency chart

# %%
# Import the library
import matplotlib.pyplot as plot
# %matplotlib inline  
# Magic to allow the graph to display directly in this notebook

# Create bins/dividers for your data
bins = [4, 5, 6, 7, 8]

# plot.hist(array, bins, alignment, graph color, border color)
plot.hist(total_arr, bins, align='left', color='lightgreen', edgecolor='black', rwidth=.7)
plot.xlabel("Frequency")
plot.ylabel("Games Played")
plot.title("Average Total Games Played To Win a World Series")
plot.show()

# %% [markdown]
# #### Pie Chart
# * Percentage chart

# %%
# source: http://matplotlib.org/examples/pie_and_polar_charts/pie_demo_features.html

# Import the library
import matplotlib.pyplot as plot
# %matplotlib inline
# Magic to allow the graph to display directly in this notebook

# Create an array of labels
labels = ["4 Games", "5 Games", "6 Games", "7 Games"]

# Since we recrop the total bincount each time we must redefine the bincount
total_bincount = np.bincount(total_arr)
# Crop the game_bin array to exclude the 0's
    # Only need indices 4 to the end
total_bincount = total_bincount[4:]
# Explode option
    # 'Slices' appear distanced from the center
        # Larger numbers = further explosion
    # Explode array should be same size as labels and
explode = (.01, .01, .01, .01)

# Use matplotlib module subplots() to get data for various charts
    # Returns a tuple in the form (figure,axes)
fig1,ax1 = plot.subplots()

# Use axes to create a pie chart
    # ax1.pie(data array, explode array, labels array, starting angle)
ax1.pie(total_bincount, explode, labels, autopct='%1.1f%%', startangle=90, textprops={"color": "white", "size": "x-large"})
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plot.show()

# %% [markdown]
# ### Don't forget to answer the original question!
# * Answer should be in the form of a complete sentence

# %% [markdown]
# According to the simulation on average it will take 5.6987 games for a world series to conclude.

# %% [markdown]
# ## Additional data points
# * How many times did an American League team win the World Series compared to the National League?

# %%
# Create variables
# winning_division_array = []

# **I chose not to as all of this simply creates my winner_arr above**

# Loop through each individual World Series within the ws_results array
    # Store first value of the tuple at index 0 (winning division)
    # Add winning division to the winning_division_array
# for world_series in ws_results:
#     division = world_series[0]
#     winning_division_array.append(division)

# Print results
print(winner_arr)
# Out:
# ['American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'National League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'National League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'National League', 'National League', 'American League', 'American League', 'National League', 'American League', 'National League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'American League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National League', 'American League', 'American League', 'National ...

# %% [markdown]
# #### Count the totals of NL and AL
# * Loop through each winning division in the array
# * Update a count for each division accordingly

# %%
# Create variables
total_al = 0
total_nl = 0

# Loop through each division in the winning_division_array, update wins
for victor in winner_arr:
    if victor == "American League":
        total_al = total_al + 1
    else:
        total_nl = total_nl + 1

# Display results
print("Number NL wins: " + str(total_nl))
print("Number AL wins: " + str(total_al))
# Out:
# Number NL wins: 2857
# Number AL wins: 7143

# %% [markdown]
# ### Don't forget to answer the original question!
# * Answer should be in the form of a complete sentence

# %% [markdown]
# The American League won 7143 times according to the simulation.
#
# The National League won 2857 times according to the simulation.

# %% [markdown]
# ###  What else can you learn from this data?  In the markdown cell below, list at least 2 questions that you would be able to answer by further analyzing the data.  (Note:  you do not need to actually answer the questions).

# %% [markdown]
# What is the winrate of the National League as a percentage?

# %% [markdown]
# How often did the series go to five matches?
